# %%
import pandas as pd


shift_path = "/mnt/pandapower/grid_simulation/src/output_test/datacenter_result_spatial_shift.csv"
baseline_path = "/mnt/pandapower/grid_simulation/src/output_test/datacenter_result_none.csv"
